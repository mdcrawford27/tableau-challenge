# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/mdcra/Desktop/tableau-challenge/csv_data/2020-06.csv")

# %%
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          3810  6/1/2020 0:00  6/1/2020 1:03               366
# 1           355  6/1/2020 0:00  6/1/2020 0:06               248
# 2            99  6/1/2020 0:00  6/1/2020 0:02              3232
# 3            87  6/1/2020 0:00  6/1/2020 0:02               390
# 4          2714  6/1/2020 0:00  6/1/2020 0:46               319
#
#             start station name  start station latitude  \
# 0     Clinton Ave & Myrtle Ave               40.693261
# 1        Laight St & Hudson St               40.721854
# 2          Bond St & Fulton St               40.689622
# 3  Duffield St & Willoughby St               40.692216
# 4         Fulton St & Broadway               40.711066
#
#    start station longitude  end station id             end station name  \
# 0               -73.968896             336  Sullivan St & Washington Sq
# 1               -74.007718             247       Perry St & Bleecker St
# ...

# %%
df2 = df[df["usertype"] == 'Subscriber']

# %%
df3 = df2[df2["birth year"] > 1950]

# %%
df4 = df3[df3["gender"] > 0]

# %%
df4.to_csv("C:/Users/mdcra/Desktop/tableau-challenge/csv_data/2020_06_Subscribers.csv")
